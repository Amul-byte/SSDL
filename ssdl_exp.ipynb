# %%
import os
os.listdir()
# Out:
# ['.config',
#  'train.py',
#  'SmartFallMM-Dataset',
#  'generate.py',
#  'requirements.txt',
#  'README.md',
#  'diffusion_model',
#  'results_visual',
#  'figures',
#  'ssdl_exp.ipynb',
#  'hello.py',
#  '.ipynb_checkpoints',
#  'requirements_clean.txt',
#  'sample_data']

# %%
os.chdir("drive/MyDrive/Colab Notebooks/SSDL")

# %%
os.listdir()
# Out:
# ['.config',
#  'train.py',
#  'SmartFallMM-Dataset',
#  'generate.py',
#  'requirements.txt',
#  'README.md',
#  'diffusion_model',
#  'results_visual',
#  'figures',
#  'ssdl_exp.ipynb',
#  'hello.py',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
# !python hello.py
# Out:
# helloworld

# %%
# !pip install -r requirements_clean.txt
